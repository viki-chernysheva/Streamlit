# %% [markdown]
# # Веб-приложение

# %% [markdown]
# ## 1. Что такое веб-приложение
# [Как вы думаете, что происходит между сменой городов и отображением карты](https://yandex.ru/metro)

# %% [markdown]
# ## 2. Основы веб-разработки
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSr84TOHkALxjCEeV9v3TklHXBtAfgQnMGhw5xcDZLlGw&s=10)

# %% [markdown]
# ## 3. Передача кода
# [Pastobin онлайн](https://convertilo.ru/tools/pastebin/)
#
# ## 4. Домашнее задание "Улучши планировщик путешествий"
# 1. Добавь новый блок в типах отдыха и обнови условие в соответствии с новым типом
# 2. Добавь новую страну.
# 3. Добавь для неё информацию по типам.
# 4. Доп: замени изображение фона
